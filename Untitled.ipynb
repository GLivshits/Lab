# %%
import pandas as pd

# %%
df = pd.read_csv(r'C:\Users\kpebe\OneDrive\Рабочий стол\Parylene\Parylene top contact\First measurement\data\fet_1_1.csv',
                 engine = 'python', sep = ',')

# %%
df
# Out:
#     Vsd    Vg          Isd1           Ig1
# 0   1.0 -10.0  5.140000e-12 -4.600000e-11
# 1   1.0  -8.0  2.320000e-12 -3.800000e-11
# 2   1.0  -6.0  1.160000e-12 -3.100000e-11
# 3   1.0  -4.0 -1.000000e-13 -3.900000e-11
# 4   1.0  -2.0 -6.700000e-13 -3.100000e-11
# 5   1.0   0.0 -9.500000e-13 -3.800000e-11
# 6   1.0   2.0  4.000000e-13 -3.100000e-11
# 7   1.0   4.0 -1.750000e-12 -2.500000e-11
# 8   1.0   6.0 -2.470000e-12 -2.200000e-11
# 9   1.0   8.0 -2.630000e-12 -2.600000e-11
# 10  1.0  10.0 -3.420000e-12 -2.100000e-11
# 11  1.0  10.0 -2.450000e-12 -2.800000e-11
# 12  1.0   8.0 -1.380000e-12 -2.600000e-11
# 13  1.0   6.0 -5.500000e-13 -3.800000e-11
# 14  1.0   4.0  7.300000e-13 -3.200000e-11
# 15  1.0   2.0  9.900000e-13 -3.300000e-11
# 16  1.0   0.0  1.500000e-12 -3.400000e-11
# 17  1.0  -2.0  1.750000e-12 -4.100000e-11
# 18  1.0  -4.0  2.390000e-12 -3.800000e-11
# 19  1.0  -6.0  3.060000e-12 -4.000000e-11
# 20  1.0  -8.0  3.390000e-12 -3.900000e-11
# ...

# %%
print('\t')
# Out:
# /t
